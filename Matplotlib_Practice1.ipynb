# %%
import matplotlib.pyplot as plt

years = [1000,1500,1600,1700,1750,1800,1850,
        1900,1950,1960,1965,1970,1975,1980,
        1985,1990,1995,2000,2005,
        2010,2015]

pops = [200,400,458,580,662,791,1000,
        1262,1650,2525,2758,3018,3322,3682,
        4061,4440,4853,5310,6520,
        6930,7349]

#plt.plot() 使用plt.plot()，將years,pops資料內容放到函數內
plt.plot(years,pops)

#plt.show() 接著要將圖表顯示出來
plt.show()

# %%
#change color 要怎麼改變線條的顏色呢？ 只需要在plt.plot()內加入一個color參數
plt.plot(years,pops,color=(255/255,100/255,100/255))
plt.show()

# %%
#label 會基本的將圖型顯示出來之後，可以新增label，我們來寫個人口成長的圖表
years = [1950,1960,1965,1970,1975,1980,
        1985,1990,1995,2000,2005,
        2010,2015]
pops = [2.5,2.7,3,3.3,3.6,4.0,
        4.4,4.8,5.3,6.1,6.5,6.9,7.3]

#設定label：
plt.title("Population Growth") # title
plt.ylabel("Population in billions") # y label
plt.xlabel("Population growth by year") # x label

plt.plot(years,pops,color=(255/255,100/255,100/255))
plt.show()

# %%
#Multilines 上面我們顯示了人口成長的圖表，假設我們想再加上死亡率
deaths = [1.2,1.7,1.8,2.2,2.5,2.7,2.9,3,3.1,3.2,3.5,3.6,4]

#label 會基本的將圖型顯示出來之後，可以新增label，我們來寫個人口成長的圖表
years = [1950,1960,1965,1970,1975,1980,
        1985,1990,1995,2000,2005,
        2010,2015]
pops = [2.5,2.7,3,3.3,3.6,4.0,
        4.4,4.8,5.3,6.1,6.5,6.9,7.3]

#設定label：
plt.title("Population Growth") # title
plt.ylabel("Population in billions") # y label
plt.xlabel("Population growth by year") # x label

#將它們寫在一起，都是一樣的
lines = plt.plot(years,pops,years,deaths)
'''
plt.plot(years,pops, color=(255/255,100/255,100/255))
plt.plot(years,deaths, '--', color=(100/255,100/255,255/255))
'''

plt.show()

# %%
#Configure graph 能夠顯示多筆資料了，接下來看看圖型可以有哪些設置吧

#先用一樣的資料

years = [1950,1960,1965,1970,1975,1980,
        1985,1990,1995,2000,2005,
        2010,2015]
pops = [2.5,2.7,3,3.3,3.6,4.0,
        4.4,4.8,5.3,6.1,6.5,6.9,7.3]
deaths = [1.2,1.7,1.8,2.2,2.5,2.7,2.9,3,3.1,3.2,3.5,3.6,4]

plt.title("Population Growth") # title
plt.ylabel("Population in billions") # y label
plt.xlabel("Population growth by year") # x label

lines = plt.plot(years,pops,years,deaths)

#plt.grid() grid()用來顯示網格：
plt.grid(True)

plt.show()

# %%
years = [1950,1960,1965,1970,1975,1980,
        1985,1990,1995,2000,2005,
        2010,2015]
pops = [2.5,2.7,3,3.3,3.6,4.0,
        4.4,4.8,5.3,6.1,6.5,6.9,7.3]
deaths = [1.2,1.7,1.8,2.2,2.5,2.7,2.9,3,3.1,3.2,3.5,3.6,4]

plt.title("Population Growth") # title
plt.ylabel("Population in billions") # y label
plt.xlabel("Population growth by year") # x label

lines = plt.plot(years,pops,years,deaths)

#plt.setp() 接下來我們來設定線的mark
#我們將要繪的線都放到lines這個變數內，再來就可以用plt.setp()
plt.setp(lines,marker = "o") 

plt.grid(True)

plt.show()

# %%
#With Numpy： 結合Numpy來繪出兩個不同速率的sin波形吧

import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 1.0, 0.01)
y1 = np.sin(4*np.pi*x)
y2 = np.sin(2*np.pi*x)
lines = plt.plot(x, y1, x, y2)
#l1, l2 = lines
plt.setp(lines, linestyle='--')      
plt.show()
